# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sentisignal

# %%
# notebook-wide experiemental configuration
data_primary = '../../data/csv/stocktwits_twitter_withretweets_daily.csv'
data_symbology = '../../data/csv/symbology.csv'
data_pickles = '../../data/pickles/'
start_date = '2013-01-01'
end_date = '2015-01-01'

# %%
a_sent_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 0)
g_sent_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p

# %%
a_vol_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 0)
g_vol_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_LOG_BULLISHNESS_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_LOG_BULLISHNESS_LOG_RETURN_-1_True.p

# %%
a_sent_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 30)
g_sent_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p

# %%
a_vol_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 30)
g_vol_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_LOG_RETURN_-1_True.p

# %%
sentisignal.plot_info_surplus([a_sent_0, g_sent_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_0, g_vol_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_sent_30, g_sent_30], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_30, g_vol_30], ["AAPL", "GOOG"])
