# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sentisignal

# %%
# notebook-wide experiemental configuration
data_primary = '../../data/csv/stocktwits_twitter_withretweets_daily.csv'
data_symbology = '../../data/csv/symbology.csv'
data_pickles = '../../data/pickles/'
start_date = '2013-01-01'
end_date = '2015-01-01'

# %%
a_sent_price_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 0)
g_sent_price_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p

# %%
a_sent_vol_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'VOLUME', -1, True, 0)
g_sent_vol_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'VOLUME', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_BULL_MINUS_BEAR_VOLUME_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_BULL_MINUS_BEAR_VOLUME_-1_True.p

# %%
a_vol_price_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 0)
g_vol_price_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_LOG_BULLISHNESS_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_LOG_BULLISHNESS_LOG_RETURN_-1_True.p

# %%
a_vol_vol_0 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'VOLUME', -1, True, 0)
g_vol_vol_0 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'VOLUME', -1, True, 0)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_LOG_BULLISHNESS_VOLUME_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_LOG_BULLISHNESS_VOLUME_-1_True.p

# %%
a_sent_price_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 30)
g_sent_price_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'LOG_RETURN', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_LOG_RETURN_-1_True.p

# %%
a_sent_vol_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'VOLUME', -1, True, 30)
g_sent_vol_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'BULL_MINUS_BEAR', 'VOLUME', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_VOLUME_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_BULL_MINUS_BEAR_VOLUME_-1_True.p

# %%
a_vol_price_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 30)
g_vol_price_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'LOG_RETURN', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_LOG_RETURN_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_LOG_RETURN_-1_True.p

# %%
a_vol_vol_30 = sentisignal.load_information_surplus(data_pickles, 'AAPL', start_date, end_date, 5, 'LOG_BULLISHNESS', 'VOLUME', -1, True, 30)
g_vol_vol_30 = sentisignal.load_information_surplus(data_pickles, 'GOOG', start_date, end_date, 5, 'LOG_BULLISHNESS', 'VOLUME', -1, True, 30)
# Out:
# Load pickle: ../../data/pickles/info_surp_res/AAPL_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_VOLUME_-1_True.p
# Load pickle: ../../data/pickles/info_surp_res/GOOG_2013-01-01_2015-01-01_30_LOG_BULLISHNESS_VOLUME_-1_True.p

# %%
sentisignal.plot_info_surplus([a_sent_price_0, g_sent_price_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_sent_vol_0, g_sent_vol_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_price_0, g_vol_price_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_vol_0, g_vol_vol_0], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_sent_price_30, g_sent_price_30], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_sent_vol_30, g_sent_vol_30], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_price_30, g_vol_price_30], ["AAPL", "GOOG"])

# %%
sentisignal.plot_info_surplus([a_vol_vol_30, g_vol_vol_30], ["AAPL", "GOOG"])

# %%
sentisignal.km

# %%
d = {'MIn' : sentisignal.pd.Series([5, 5, 6, 4, 4, 3, 3, 2, 2, 1, 1, 10, 12, 3, -5, 8, 9, 1, 1]),
     'Lag' : sentisignal.pd.Series([2, 2, 2, 4, 5, 6, 6, 7, 1, 9, 12, 1, 1, 10, 10, 2, 2, 8, 7]),
     'Sec' : sentisignal.pd.Series([1, 2, 1, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, 3, 3, 1, 2, 3, 3]),
     'Exc' : sentisignal.pd.Series([1, 1, 1, 1, 1, 1, 2, 2, 2, 3, 3, 1, 1, 2, 2, 1, 1, 1, 1]),
    }

# %%
df = sentisignal.pd.DataFrame(d)

# %%
df
# Out:
#     Exc  Lag  MIn  Sec
# 0     1    2    5    1
# 1     1    2    5    2
# 2     1    2    6    1
# 3     1    4    4    3
# 4     1    5    4    3
# 5     1    6    3    3
# 6     2    6    3    3
# 7     2    7    2    3
# 8     2    1    2    3
# 9     3    9    1    3
# 10    3   12    1    3
# 11    1    1   10    1
# 12    1    1   12    1
# 13    2   10    3    3
# 14    2   10   -5    3
# 15    1    2    8    1
# 16    1    2    9    2
# 17    1    8    1    3
# 18    1    7    1    3

# %%
sentisignal.kmeans(df, ['Exc', 'MIn', 'Lag', 'Sec'])
