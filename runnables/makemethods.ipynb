# %%
from sentisignal import *

# %%
# %matplotlib inline

# %%
# full dataset
# subsampled_data = subsample_data('../../data/csv/stocktwits_twitter_withretweets_daily.csv', '2015-01-01', '2015-02-02')
# subsamples dataset for speed
# subsampled_data = subsample_data('../../data/subsample_csv/stocktwits_twitter_withretweets_daily_subsample.csv', '../../data/csv/symbology.csv', '2014-01-01', '2015-01-01', 'SYMBOL', ['GPI', 'ABB'])
subsampled_data = sesubsample_data('../../data/subsample_csv/stocktwits_twitter_withretweets_daily_subsample.csv', '../../data/csv/symbology.csv', '2014-01-01', '2015-01-01', 'EXCHANGE', ['NASDAQ'])

# %%
subsampled_data.head()
# Out:
#                              SOURCE SYMBOL         TIMESTAMP_UTC  \
# 8   stocktwits+twitter_withretweets   GEVO  2014-11-19T05:00:00Z
# 9   stocktwits+twitter_withretweets   MITL  2014-01-03T05:00:00Z
# 10  stocktwits+twitter_withretweets   SCON  2014-10-08T04:00:00Z
# 17  stocktwits+twitter_withretweets   BOKF  2014-01-10T05:00:00Z
# 20  stocktwits+twitter_withretweets   ENTA  2014-09-08T04:00:00Z
#
#     BULLISH_INTENSITY  BEARISH_INTENSITY  BULL_MINUS_BEAR  \
# 8                0.00               1.92            -1.92
# 9                2.34               0.00             2.34
# 10               0.00               0.00             0.00
# 17               0.00               2.22            -2.22
# 20               1.56               2.67            -1.11
#
#     BULL_SCORED_MESSAGES  BEAR_SCORED_MESSAGES  BULL_BEAR_MSG_RATIO  \
# 8                      0                     4                    0
# 9                      1                     0                    0
# ...

# %%
subsampled_data['EXCHANGE'].unique()
# Out:
# array(['NASDAQ'], dtype=object)
