# %% [markdown]
# # Final Notebook 001 - Data Acquisition and Descriptive Statistics

# %% [markdown]
# ## Import

# %%
import sentisignal
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np 
import pylab as P 
import ast
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import math
import scipy.stats as s
import statsmodels.api as sm
import pprint
import seaborn as sns

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from datetime import datetime
from yahoo_finance import Share
from pandas_datareader import data, wb
from statsmodels.graphics.api import qqplot
from operator import itemgetter
from decimal import *

# plt.style.use('ggplot')
# sns.set_style("darkgrid")
# sns.set_context("notebook")

# %% [markdown]
# ## Configuration

# %%
data_primary_path = '../../data/csv/stocktwits_twitter_withretweets_daily.csv'
data_symbology_path = '../../data/csv/symbology.csv'
data_pickles_path = '../../data/pickles/'
data_nasdaq_company_list_path = '../../data/nasdaq/companylist.csv'
start_date = '2012-01-01'
end_date = '2012-01-07'

# %%
plot_width = 8
plot_height = 8

# %% [markdown]
# ## NASDAQ Data

# %%
data_symbology = pd.read_csv(data_symbology_path)

# %% [markdown]
# ### Use NASDAQ data to get top 100 companies by MarketCap

# %%
data_nasdaq_company_list = pd.read_csv(data_nasdaq_company_list_path)
data_nasdaq_top_100_mkt_cap = data_nasdaq_company_list.head(100)
data_nasdaq_top_100_mkt_cap_symbols = data_nasdaq_top_100_mkt_cap['Symbol'].unique()

# %% [markdown]
# ### Calculate breakdown per sector (using PsychSignal symbology)

# %%
data_nasdaq_top_100_mkt_cap_symbology = pd.merge(data_nasdaq_top_100_mkt_cap, data_symbology, left_on='Symbol', right_on='symbol', how = "left")
# data_nasdaq_top_100_mkt_cap_symbology.info()
data_nasdaq_top_100_mkt_cap_symbology_sector_size = data_nasdaq_top_100_mkt_cap_symbology.groupby(['sector']).size()
print data_nasdaq_top_100_mkt_cap_symbology_sector_size
# Out:
# sector
# Consumer Goods       4
# Financial            7
# Healthcare          13
# Industrial Goods     1
# Services            25
# Technology          30
# dtype: int64

# %%
data_nasdaq_top_100_mkt_cap_symbology_sector_size.plot(kind='pie', autopct='%.1f')
plt.axis('equal')
# plt.title('NASAQ Top 100 (by MarketCap) by Sector')
# Out:
# (-1.0128662320463357, 1.0, -1.0193658825849057, 1.0141629122482432)

# %% [markdown]
# ### Calculate and graph yearly mean of average monthly messages

# %%
sum_avg_cols = [col for col in data_nasdaq_top_100_mkt_cap_symbology.columns if ('all_scanned_20' in col and 'avg_monthly' in col)]
data_nasdaq_top_100_mkt_cap_symbology['mean_avg_monthly'] = data_nasdaq_top_100_mkt_cap_symbology[sum_avg_cols].sum(axis=1)/len(sum_avg_cols)

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)
data_nasdaq_top_100_mkt_cap_symbology['mean_avg_monthly'].plot(kind='bar')
ax.set_xticklabels(data_nasdaq_top_100_mkt_cap_symbology['symbol'], rotation=90)
plt.ylabel('Mean Avg. Monthly Message Volume')
plt.xlabel('Company')
plt.show()

# %%
data_nasdaq_top_100_mkt_cap_symbology.hist(column=['mean_avg_monthly'])
plt.ylabel('Frequency')
plt.xlabel('Mean Avg. Monthly Message Volume')
plt.title('')

# %% [markdown]
# ### Correlation matrix

# %%
sentisignal.plot_corr(data_nasdaq_top_100_mkt_cap_symbology)

# %% [markdown]
# ### MarketCap and mean_avg_monthly regression

# %%
data_nasdaq_top_100_mkt_cap_symbology.plot(kind='scatter', x='MarketCap', y='mean_avg_monthly')
x = data_nasdaq_top_100_mkt_cap_symbology['MarketCap']
y = data_nasdaq_top_100_mkt_cap_symbology['mean_avg_monthly']
idx = np.isfinite(x) & np.isfinite(y)
m, b = np.polyfit(x[idx], y[idx], 1)
plt.plot(x, m*x + b, '-')

# %% [markdown]
# ## Subsample sentiment data (Daily Stocktwits and Twitter with retweets)

# %%
data_nasdaq_top_100_sentiment = sentisignal.subsample_data(data_primary_path, data_symbology_path, data_pickles_path, start_date, end_date, 'SYMBOL', data_nasdaq_top_100_mkt_cap_symbols, False)
data_nasdaq_top_100_sentiment.head()
# Out:
# Loaded from pre-created pickle
#                                 SOURCE SYMBOL         TIMESTAMP_UTC  \
# 13057  stocktwits+twitter_withretweets    AAL  2012-01-03T05:00:00Z
# 13058  stocktwits+twitter_withretweets    AAL  2012-01-04T05:00:00Z
# 13059  stocktwits+twitter_withretweets    AAL  2012-01-05T05:00:00Z
# 13060  stocktwits+twitter_withretweets    AAL  2012-01-06T05:00:00Z
# 20653  stocktwits+twitter_withretweets   AAPL  2012-01-01T05:00:00Z
#
#        BULLISH_INTENSITY  BEARISH_INTENSITY  BULL_MINUS_BEAR  \
# 13057               0.00               1.50            -1.50
# 13058               0.00               0.00             0.00
# 13059               0.00               0.00             0.00
# 13060               0.00               0.00             0.00
# 20653               1.63               1.97            -0.34
#
#        BULL_SCORED_MESSAGES  BEAR_SCORED_MESSAGES  BULL_BEAR_MSG_RATIO  \
# 13057                     0                     1                 0.00
# 13058                     0                     0                 0.00
# 13059                     0                     0                 0.00
# 13060                     0                     0                 0.00
# 20653                    19                     4                 4.75
#
#        TOTAL_SCANNED_MESSAGES EXCHANGE      SECTOR            INDUSTRY  \
# 13057                       2   NASDAQ         NaN                 NaN
# 13058                       1   NASDAQ         NaN                 NaN
# 13059                       2   NASDAQ         NaN                 NaN
# 13060                       3   NASDAQ         NaN                 NaN
# 20653                     348   NASDAQ  Technology  Personal Computers
#
#                          TITLE       DATE
# 13057  American Airlines Group 2012-01-03
# 13058  American Airlines Group 2012-01-04
# 13059  American Airlines Group 2012-01-05
# 13060  American Airlines Group 2012-01-06
# 20653               Apple Inc. 2012-01-01

# %% [markdown]
# ## Scrape finance data (Yahoo! Finance)

# %%
data_nasdaq_top_100_finance = sentisignal.get_data_finance('yahoo', data_nasdaq_top_100_mkt_cap_symbols, start_date, end_date, data_pickles_path, False, 'NaN')
data_nasdaq_top_100_finance.head()
# Out:
# Scraping and saving data from yahoo
# AAPL
# GOOGL
# GOOG
# MSFT
# FB
# Unable to retrieve data for: FB
# AMZN
# CMCSA
# INTC
# CSCO
# GILD
# AMGN
# KHC
# Unable to retrieve data for: KHC
# SBUX
# WBA
# CELG
# QCOM
# COST
# MDLZ
# PCLN
# BIIB
# TXN
# FOX
# BIDU
# ESRX
# PYPL
# Unable to retrieve data for: PYPL
# NFLX
# ADBE
# REGN
# AVGO
# ADP
# QQQ
# CTSH
# FOXA
# ALXN
# CME
# YHOO
# LBTYA
# TMUS
# LILAK
# Unable to retrieve data for: LILAK
# LBTYK
# LILA
# Unable to retrieve data for: LILA
# EBAY
# TSLA
# NXPI
# LBTYB
# MNST
# ORLY
# INTU
# AAL
# CSX
# LVNTA
# Unable to retrieve data for: LVNTA
# ROST
# DISH
# JD
# Unable to retrieve data for: JD
# ATVI
# ILMN
# LVNTB
# Unable to retrieve data for: LVNTB
# MYL
# AMAT
# VRTX
# FISV
# EQIX
# ISRG
# CHTR
# EA
# SIRI
# PAYX
# PCAR
# DLTR
# TROW
# CERN
# NVDA
# MAR
# QVCB
# ADI
# VIA
# AMTD
# QVCA
# EXPE
# CHKP
# IBKR
# SNDK
# NTRS
# BMRN
# SWKS
# CTRP
# HSIC
# VIAB
# INCY
# FITB
# FAST
# VRSK
# LMCA
# Unable to retrieve data for: LMCA
# ADSK
# VOD
# LMCK
# Unable to retrieve data for: LMCK
# MU
# CA
# LMCB
# Unable to retrieve data for: LMCB
# SBAC
#           DATE        OPEN        HIGH         LOW       CLOSE    VOLUME  \
# 0   2012-01-03  409.399998  412.499989  408.999989  411.230000  75555200
# 216 2012-01-03  470.950012  473.929993  467.170013  471.709991    344600
# 92  2012-01-03   28.700001   29.010000   28.510000   28.570000   4495100
# 220 2012-01-03   57.520000   57.790001   57.000000   57.189999    792200
# 88  2012-01-03   70.280000   72.720002   70.130003   72.239998  29213800
#
#       ADJ CLOSE SYMBOL
# 0     54.405100   AAPL
# 216  471.709991   ISRG
# 92    28.570000   ADBE
# 220   57.189999   CHTR
# 88    10.320000   NFLX

# %% [markdown]
# ### Preprocess and merge

# %%
# preprocess creating additional statistics 
[data_nasdaq_top_100_sentiment_preprocessed, data_nasdaq_top_100_finance_preprocessed] = sentisignal.preprocess_per_symbol(data_nasdaq_top_100_sentiment, data_nasdaq_top_100_finance)

# %%
# insert preprocessing steps here
data_nasdaq_top_100_merge = sentisignal.merge_sentiment_finance(data_nasdaq_top_100_sentiment, data_nasdaq_top_100_finance, True, True, True)

# %%
data_nasdaq_top_100_preprocessed_merge = sentisignal.merge_sentiment_finance(data_nasdaq_top_100_sentiment_preprocessed, data_nasdaq_top_100_finance_preprocessed, True, True, True)

# %% [markdown]
# ### Correlation matrix

# %%
sentisignal.plot_corr(data_nasdaq_top_100_merge)

# %%
sentisignal.plot_corr(data_nasdaq_top_100_preprocessed_merge)

# %%
data_nasdaq_top_100_preprocessed_merge.describe()
# Out:
#        BULLISH_INTENSITY  BEARISH_INTENSITY  BULL_MINUS_BEAR  \
# count         283.000000         283.000000       283.000000
# mean            1.265548           0.943074         0.322473
# std             0.952117           0.990937         1.297780
# min             0.000000           0.000000        -3.100000
# 25%             0.000000           0.000000        -0.300000
# 50%             1.560000           0.620000         0.000000
# 75%             2.020000           1.810000         1.375000
# max             3.220000           3.100000         3.220000
#
#        BULL_SCORED_MESSAGES  BEAR_SCORED_MESSAGES  BULL_BEAR_MSG_RATIO  \
# count            283.000000            283.000000           283.000000
# mean              13.773852              6.197880             1.473993
# std               40.202745             20.368669             3.049310
# min                0.000000              0.000000             0.000000
# 25%                0.000000              0.000000             0.000000
# 50%                2.000000              1.000000             0.000000
# 75%                8.000000              3.000000             2.000000
# max              413.000000            164.000000            21.000000
#
#        TOTAL_SCANNED_MESSAGES  LOG_BULL_RETURN  LOG_BEAR_RETURN  \
# count              283.000000       267.000000       267.000000
# mean                66.618375         0.206012         0.125673
# std                192.775020         1.043068         0.913233
# min                  1.000000        -1.945910        -2.302585
# 25%                  4.000000        -0.573701        -0.327463
# 50%                 10.000000         0.000000         0.000000
# 75%                 34.000000         0.759913         0.693147
# max               1862.000000         3.135494         3.367296
#
#        LOG_BULLISHNESS       ...         TOTAL_SENTIMENT_MESSAGES_DIFF  \
# count       283.000000       ...                            267.000000
# mean          0.507290       ...                              5.220974
# std           0.909512       ...                             35.560494
# min          -2.302585       ...                           -164.000000
# 25%           0.000000       ...                             -2.000000
# 50%           0.693147       ...                              0.000000
# 75%           1.098612       ...                              4.000000
# max           3.332205       ...                            341.000000
#
#              OPEN        HIGH         LOW       CLOSE        VOLUME  \
# count  283.000000  283.000000  283.000000  283.000000  2.830000e+02
# mean    72.702985   73.636165   71.955740   72.932030  1.170290e+07
# std    114.928549  115.928035  113.858895  115.019982  2.002285e+07
# min      1.840000    1.880000    1.800000    1.830000  1.380000e+04
# 25%     24.595001   24.960000   24.439999   24.710000  2.032400e+06
# 50%     38.939999   39.490002   38.750000   39.360001  4.495100e+06
# 75%     63.959999   64.895000   63.425002   64.260002  1.013630e+07
# max    665.031159  670.251161  660.621128  668.281154  1.256108e+08
#
#         ADJ CLOSE  LOG_RETURN  VOLATILITY  LOG_VOLUME_DIFF
# count  283.000000  210.000000  283.000000       108.000000
# mean    53.544266    0.005909    1.680424        13.813136
# std     84.845680    0.021353    2.370903         1.828370
# min      1.796968   -0.048579    0.050000         6.802395
# 25%     20.641906   -0.006646    0.505000        12.720231
# 50%     30.809999    0.004485    0.870003        13.729299
# 75%     50.010047    0.013784    1.569999        14.841407
# max    486.209991    0.108634   15.780023        18.082072
#
# [8 rows x 25 columns]

# %%
sns.clustermap(data_nasdaq_top_100_preprocessed_merge.corr())

# %%
sentisignal.check_pdf(data_nasdaq_top_100_preprocessed_merge)
# Out:
# LOG_BULL_RETURN error
# LOG_BEAR_RETURN error
# LOG_BULL_BEAR_RATIO error
# LOG_BULL_MINUS_BEAR_CHANGE error
# RTISf error
# TOTAL_SCANNED_MESSAGES_DIFF error
# TOTAL_SENTIMENT_MESSAGES_DIFF error
# LOG_RETURN error
# LOG_VOLUME_DIFF error

# %%
sentisignal.check_acf(data_nasdaq_top_100_preprocessed_merge)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## Save results to intermediate pick

# %%
data_nasdaq_top_100_preprocessed_merge.to_pickle(data_pickles_path+'intermediate/'+'data_nasdaq_top_100_preprocessed_merge_'+start_date+'_'+end_date)

# %% [markdown]
# ## Apply rolling window and repeat analysis

# %%
data_nasdaq_top_100_preprocessed_merge_window_30 = sentisignal.split_apply_combine(data_nasdaq_top_100_preprocessed_merge, 'SYMBOL', sentisignal.apply_rolling_window, [30])
# Out:
#   File "<ipython-input-140-61e20d2fafb9>", line 1
#     data_nasdaq_top_100_preprocessed_merge_window_30 = sentisignal.split_apply_combine(data_nasdaq_top_100_preprocessed_merge, 'SYMBOL', sentisignal.apply_rolling_window, [width=30])
#                                                                                                                                                                                  ^
# SyntaxError: invalid syntax
